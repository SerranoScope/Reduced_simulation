# %%
# import numpy as np
import numpy as np
import pandapipes as pp
from pandapipes.pf.pipeflow_setup import get_fluid
# 1. Crear red vacía
net = pp.create_empty_network(fluid="water")

# =============================================================================
# NUDOS (JUNCTIONS)
# =============================================================================
# Nota: Las temperaturas en pandapipes se introducen en Kelvin (K = °C + 273.15)
# Ida 
j_fuente_ida = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Fuente_Ida")
j_fuente_2_ida = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Fuente_2_Ida")
j_fuente_3_ida = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Fuente_3_Ida")
j_nodo_1=pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Nodo1_ida")
j_nodo_2=pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Nodo2_ida")
j_nodo_3=pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Nodo3_ida")
j_nodo_4=pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Nodo4_ida")
j_nodo_5=pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Nodo5_ida")
j_nodo_6=pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Nodo6_ida")
j_cons_ida_1 = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Consumidor1_Ida")
j_cons_ida_2 = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Consumidor2_Ida")
j_cons_ida_3 = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Consumidor3_Ida")
j_cons_ida_4 = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Consumidor4_Ida")
j_cons_ida_5 = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Consumidor5_Ida")
j_cons_ida_6 = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Consumidor6_Ida")
j_cons_ida_7 = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Consumidor7_Ida")
j_cons_ida_8 = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Consumidor8_Ida")
j_cons_ida_9 = pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Consumidor9_Ida")
#Retorno 
j_fuente_ret = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Fuente_Retorno")
j_fuente_2_ret = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Fuente_2_Retorno")
j_fuente_3_ret = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Fuente_3_Retorno")
j_nodo_1_ret=pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Nodo1_ret")
j_nodo_2_ret=pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Nodo2_ret")
j_nodo_3_ret=pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Nodo3_ret")
j_nodo_4_ret=pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Nodo4_ret")
j_nodo_5_ret=pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Nodo5_ret")
j_nodo_6_ret=pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Nodo6_ret")
j_cons_ret_1 = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Consumidor1_Retorno")
j_cons_ret_2 = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Consumidor2_Retorno")
j_cons_ret_3 = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Consumidor3_Retorno")
j_cons_ret_4 = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Consumidor4_Retorno")
j_cons_ret_5 = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Consumidor5_Retorno")
j_cons_ret_6 = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Consumidor6_Retorno")
j_cons_ret_7 = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Consumidor7_Retorno")
j_cons_ret_8 = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Consumidor8_Retorno")
j_cons_ret_9 = pp.create_junction(net, pn_bar=5.0, tfluid_k=305, name="Consumidor9_Retorno")
#Inter
j_fuente_2_inter= pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Fuente_2_inter")
j_fuente_3_inter= pp.create_junction(net, pn_bar=5.0, tfluid_k=353.15, name="Fuente_3_inter")

# %%
# =============================================================================
# TUBERÍAS (PIPES) - IDA Y RETORNO SIN PÉRDIDAS TÉRMICAS (k_w = 0)
# =============================================================================

#Plant-Nodo
#Planta 1
pipe_ida_1 = pp.create_pipe_from_parameters(
    net, from_junction=j_fuente_ida, to_junction=j_nodo_1,
    length_km=0.0374, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15), text_k=273.2, name="Tubo_Ida_Plant_nodo_1",k_mm=0.1*1000
)

pipe_retorno_1= pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_1_ret, to_junction=j_fuente_ret,
    length_km=0.0374, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_RetornoPlant_nodo_1",k_mm=0.1*1000
)
#Planta 2
pipe_ida_2 = pp.create_pipe_from_parameters(
    net, from_junction=j_fuente_2_ida, to_junction=j_nodo_3,
    length_km=0.0265, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_Plant_2_nodo_3",k_mm=0.1*1000
)

pipe_retorno_2= pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_3_ret, to_junction=j_fuente_2_ret,
    length_km=0.0265, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_RetornoPlant_2_nodo_3",k_mm=0.1*1000
)
#Planta 3
pipe_ida_3 = pp.create_pipe_from_parameters(
    net, from_junction=j_fuente_3_ida, to_junction=j_nodo_6,
    length_km=0.0624, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),text_k=273.2, name="Tubo_Ida_Plant_3_nodo_6",k_mm=0.1*1000
)

pipe_retorno_3= pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_6_ret, to_junction=j_fuente_3_ret,
    length_km=0.0624, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_RetornoPlant_3_nodo_6",k_mm=0.1*1000
)
#Nodo-nodo
#1-2
pipe_ida_4 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_1, to_junction=j_nodo_2,
    length_km=0.0254, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_1_nodo_2",k_mm=0.1*1000
)
pipe_retorno_4= pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_2_ret, to_junction=j_nodo_1_ret,
    length_km=0.0254, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_1_nodo_2",k_mm=0.1*1000
    
)
#1-3
pipe_ida_5 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_1, to_junction=j_nodo_3,
    length_km=0.0316, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_1_nodo_3",k_mm=0.1*1000
)
pipe_retorno_5= pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_3_ret, to_junction=j_nodo_1_ret,
   length_km=0.0316, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_1_nodo_3",k_mm=0.1*1000  
)
#3-4
pipe_ida_6 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_3, to_junction=j_nodo_4,
    length_km=0.0498, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_3_nodo_4",k_mm=0.1*1000
)
pipe_retorno_6= pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_4_ret, to_junction=j_nodo_3_ret,
    length_km=0.0498, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_3_nodo_4",k_mm=0.1*1000   
)
#4-5
pipe_ida_7 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_4, to_junction=j_nodo_5,
    length_km=0.0349, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_4_nodo_5",k_mm=0.1*1000
)
pipe_retorno_7= pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_5_ret, to_junction=j_nodo_4_ret,
    length_km=0.0349, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_4_nodo_5",k_mm=0.1*1000   
)
#5-6
pipe_ida_8 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_5, to_junction=j_nodo_6,
    length_km=0.043, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_5_nodo_6",k_mm=0.1*1000
)
pipe_retorno_8= pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_6_ret, to_junction=j_nodo_5_ret,
    length_km=0.043, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_5_nodo_6",k_mm=0.1*1000   
)
#Nodo 2
#Consumer1
pipe_ida_9 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_2, to_junction=j_cons_ida_1,
    length_km=0.0155, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_2_consm_1",k_mm=0.1*1000
)
pipe_retorno_9= pp.create_pipe_from_parameters(
    net, from_junction=j_cons_ret_1, to_junction=j_nodo_2_ret,
    length_km=0.0155, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_2_consm_1",k_mm=0.1*1000   
)
#Consumer2
pipe_ida_10 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_2, to_junction=j_cons_ida_2,
    length_km=0.0122, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_2_consm_2",k_mm=0.1*1000
)
pipe_retorno_10= pp.create_pipe_from_parameters(
    net, from_junction=j_cons_ret_2, to_junction=j_nodo_2_ret,
    length_km=0.0122, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_2_consm_2",k_mm=0.1*1000   
)
#Consumer3
pipe_ida_11 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_2, to_junction=j_cons_ida_3,
    length_km=0.0161, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_2_consm_3",k_mm=0.1*1000
)
pipe_retorno_11= pp.create_pipe_from_parameters(
    net, from_junction=j_cons_ret_3, to_junction=j_nodo_2_ret,
    length_km=0.0161, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_2_consm_3",k_mm=0.1*1000  
)
#Nodo 4
#Consumer4
pipe_ida_12 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_4, to_junction=j_cons_ida_4,
    length_km=0.016, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_4_consm_4",k_mm=0.1*1000
)
pipe_retorno_12= pp.create_pipe_from_parameters(
    net, from_junction=j_cons_ret_4, to_junction=j_nodo_4_ret,
    length_km=0.016, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_4_consm_4",k_mm=0.1*1000
)
#Consumer5
pipe_ida_13 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_4, to_junction=j_cons_ida_5,
    length_km=0.0158, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_4_consm_5",k_mm=0.1*1000
)
pipe_retorno_13= pp.create_pipe_from_parameters(
    net, from_junction=j_cons_ret_5, to_junction=j_nodo_4_ret,
    length_km=0.0158, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_4_consm_5",k_mm=0.1*1000   
)
#Consumer6
pipe_ida_14 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_4, to_junction=j_cons_ida_6,
    length_km=0.0176, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_4_consm_6",k_mm=0.1*1000
)
pipe_retorno_14= pp.create_pipe_from_parameters(
    net, from_junction=j_cons_ret_6, to_junction=j_nodo_4_ret,
    length_km=0.0176, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_4_consm_6",k_mm=0.1*1000   
)
#Nodo 6
#Consumer7
pipe_ida_15 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_6, to_junction=j_cons_ida_7,
    length_km=0.0336, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_6_consm_7",k_mm=0.1*1000
)
pipe_retorno_15= pp.create_pipe_from_parameters(
    net, from_junction=j_cons_ret_7, to_junction=j_nodo_6_ret,
    length_km=0.0336, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_6_consm_7",k_mm=0.1*1000  
)
#Consumer8
pipe_ida_16 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_6, to_junction=j_cons_ida_8,
    length_km=0.0422, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_6_consm_8",k_mm=0.1*1000
)
pipe_retorno_16= pp.create_pipe_from_parameters(
    net, from_junction=j_cons_ret_8, to_junction=j_nodo_6_ret,
    length_km=0.0422, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_6_consm_8",k_mm=0.1*1000
)
#Consumer9
pipe_ida_17 = pp.create_pipe_from_parameters(
    net, from_junction=j_nodo_6, to_junction=j_cons_ida_9,
    length_km=0.0594, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Ida_nodo_6_consm_9",k_mm=0.1*1000
)
pipe_retorno_17= pp.create_pipe_from_parameters(
    net, from_junction=j_cons_ret_9, to_junction=j_nodo_6_ret,
    length_km=0.0594, inner_diameter_mm=150, u_w_per_m2k=0.35 / (np.pi * 0.15),  text_k=273.2, name="Tubo_Retorno_nodo_6_consm_9",k_mm=0.1*1000
)

# %%
# =============================================================================
# COMPONENTE CONSUMIDOR (Potencia en W y Temp de Retorno)
# =============================================================================
# Conectamos el nudo de ida con el de retorno. 
# El sistema extraerá agua de la ida, absorberá los Watts indicados y la devolverá al retorno a la t_return_k.

#Consm1
pp.create_heat_consumer(
    net,
    from_junction=j_cons_ida_1 ,
    to_junction=j_cons_ret_1,
    qext_w=150000,
    treturn_k=305,
    name="Consumidor_1"
)
#Consm2
pp.create_heat_consumer(
    net,
    from_junction=j_cons_ida_2,
    to_junction=j_cons_ret_2,
    qext_w=150000,
    treturn_k=305,
    name="Consumidor_2"
)
#Consm3
pp.create_heat_consumer(
    net,
    from_junction=j_cons_ida_3,
    to_junction=j_cons_ret_3,
    qext_w=150000,
    treturn_k=305,
    name="Consumidor_3"
)
#Consm4
pp.create_heat_consumer(
    net,
    from_junction=j_cons_ida_4,
    to_junction=j_cons_ret_4,
    qext_w=150000,
    treturn_k=305,
    name="Consumidor_4"
)
#Consm5
pp.create_heat_consumer(
    net,
    from_junction=j_cons_ida_5,
    to_junction=j_cons_ret_5,
    qext_w=150000,
    treturn_k=305,
    name="Consumidor_5"
)
#Consm6
pp.create_heat_consumer(
    net,
    from_junction=j_cons_ida_6,
    to_junction=j_cons_ret_6,
    qext_w=150000,
    treturn_k=305,
    name="Consumidor_6"
)
#Consm7
pp.create_heat_consumer(
    net,
    from_junction=j_cons_ida_7,
    to_junction=j_cons_ret_7,
    qext_w=150000,
    treturn_k=305,
    name="Consumidor_7"
)
#Consm8
pp.create_heat_consumer(
    net,
    from_junction=j_cons_ida_8,
    to_junction=j_cons_ret_8,
    qext_w=150000,
    treturn_k=305,
    name="Consumidor_8"
)
#Consm9
pp.create_heat_consumer(
    net,
    from_junction=j_cons_ida_9,
    to_junction=j_cons_ret_9,
    qext_w=150000,
    treturn_k=305,
    name="Consumidor_9"
)
# Out:
# np.int64(8)

# %%
# =============================================================================
# CONDICIONES DE CONTORNO (EXT_GRID)
# =============================================================================
# Primeral Central 
pp.create_circ_pump_const_pressure(net,flow_junction=j_fuente_ida,return_junction=j_fuente_ret,p_flow_bar=3,plift_bar=0.5,t_flow_k=377,name='plant_1',type=
"pt")
#Planta 2
fluid = get_fluid(net)
T_Supply_1=377
T_Return_estimative_1=305
cp_supply_1 = fluid.get_heat_capacity(T_Supply_1)
cp_return_1 = fluid.get_heat_capacity(T_Return_estimative_1)
Heat_1=250000
Delta_t_estimative=T_Supply_1-T_Return_estimative_1
M_dot_estimative_1=Heat_1/(((cp_supply_1+cp_return_1)/2)*Delta_t_estimative)


pp.create_circ_pump_const_mass_flow(
    net, return_junction=j_fuente_2_ret, flow_junction=j_fuente_2_inter,
    mdot_flow_kg_per_s=M_dot_estimative_1, t_flow_k=377, p_flow_bar=5  # valor arbitrario, ver nota abajo
)

pp.create_flow_control(
    net, from_junction=j_fuente_2_inter, to_junction=j_fuente_2_ida,
    controlled_mdot_kg_per_s=M_dot_estimative_1, loss_coefficient=0,
)
#Planta 3
T_Supply_2=376
T_Return_estimative_2=305
cp_supply_2 = fluid.get_heat_capacity(T_Supply_2)
cp_return_2 = fluid.get_heat_capacity(T_Return_estimative_2)
Heat_2=300000
Delta_t_estimative=T_Supply_2-T_Return_estimative_2
M_dot_estimative_2=Heat_2/(((cp_supply_2+cp_return_2)/2)*Delta_t_estimative)

pp.create_circ_pump_const_mass_flow(
    net, return_junction=j_fuente_3_ret, flow_junction=j_fuente_3_inter,
    mdot_flow_kg_per_s=M_dot_estimative_2, t_flow_k=376, p_flow_bar=5  # valor arbitrario, ver nota abajo
)

pp.create_flow_control(
    net, from_junction=j_fuente_3_inter, to_junction=j_fuente_3_ida,
    controlled_mdot_kg_per_s=M_dot_estimative_2, loss_coefficient=0,
)
# Out:
# np.int64(1)

# %%
pp.pipeflow(net, mode="bidirectional")

# %%
tolerance = 0.0001  # Convergence à 0.01 °C près
erreur_1=10
erreur_2=10
t_depart_consigne_1 = 377 # 90°C en Kelvin
t_retour_estime_1 = 305 # Hypothèse de départ (60°C)
t_depart_consigne_2 = 376 # 90°C en Kelvin
t_retour_estime_2 = 305   # Hypothèse de départ (60°C)

i=0
while erreur_1 > tolerance and erreur_2 > tolerance :
    print(i)
    # 1. Calcul du delta T et du débit massique basé sur l'état actuel
    delta_t_1 = t_depart_consigne_1 - t_retour_estime_1
    cp_supply = fluid.get_heat_capacity(t_depart_consigne_1)
    cp_return = fluid.get_heat_capacity(t_retour_estime_1)
    M_dot_estimative_1=Heat_1/(((cp_supply+cp_return)/2)*delta_t_1)
    delta_t_2=t_depart_consigne_2 - t_retour_estime_2
    cp_supply_2 = fluid.get_heat_capacity(t_depart_consigne_2)
    cp_return_2 = fluid.get_heat_capacity(t_retour_estime_2)
    M_dot_estimative_2=Heat_2/(((cp_supply_2+cp_return_2)/2)*delta_t_2)
    # 2. Mise à jour du flow control dans le réseau
    net.flow_control.at[0,'controlled_mdot_kg_per_s']= M_dot_estimative_1
    net.circ_pump_mass.at[0,'mdot_flow_kg_per_s']=M_dot_estimative_1
    net.flow_control.at[1,'controlled_mdot_kg_per_s']= M_dot_estimative_2
    net.circ_pump_mass.at[1,'mdot_flow_kg_per_s']=M_dot_estimative_2
    print(M_dot_estimative_1)
    print(M_dot_estimative_2)
    # 3. Exécution du calcul du réseau
    pp.pipeflow(net, mode="bidirectional")
    # 4. Lecture de la VRAIE température de retour qui arrive à l'usine
    t_retour_reel_1 = net.res_junction.loc[19, "t_k"]
    t_retour_reel_2 = net.res_junction.loc[20, "t_k"]
    print(t_retour_reel_1,t_retour_reel_2)
    # 5. Calcul de l'erreur pour le critère d'arrêt
    erreur_1 = abs(t_retour_estime_1 - t_retour_reel_1)
    erreur_2 = abs(t_retour_estime_2 - t_retour_reel_2)
    print(erreur_1,erreur_2)
    # 6. Mise à jour pour la prochaine itération
    t_retour_estime_1 = t_retour_reel_1
    t_retour_estime_2 = t_retour_reel_2
    i=i+1
# Out:
# 0
# 0.8270090298800347
# 1.0064891374156597
# 304.6253190041206 304.6035915432676
# 0.3746809958793733 0.396408456732388
# 1
# 0.8227257997786954
# 1.0008985270935118
# 304.62502361693487 304.6026742581243
# 0.0002953871857585 0.0009172851433163487
# 2
# 0.8227224405045127
# 1.0008856624702098
# 304.62502359973666 304.60267213539123
# 1.7198203750012908e-08 2.122733064879867e-06

# %%
net.res_junction.loc[19, "t_k"]
# Out:
# np.float64(304.62502359973666)

# %%
net.res_pipe
# Out:
#     v_mean_m_per_s  p_from_bar  p_to_bar    t_from_k      t_to_k  t_outlet_k  \
# 0         0.161080    3.000000  2.986069  377.000000  376.881637  376.881637
# 1         0.154717    2.513422  2.500000  304.771572  304.735253  304.735253
# 2         0.048708    2.984599  2.983693  377.000000  376.684830  376.722872
# 3         0.046785    2.515721  2.514841  304.709892  304.625024  304.625024
# 4         0.059208    2.975229  2.972077  376.000000  375.390033  375.469314
# 5         0.056917    2.526940  2.523884  304.767030  304.602672  304.602672
# 6         0.088767    2.986069  2.983192  376.881637  376.735963  376.735963
# 7         0.085273    2.516202  2.513422  304.922316  304.771572  304.877352
# 8         0.072296    2.986069  2.983693  376.881637  376.684830  376.659201
# 9         0.069447    2.515721  2.513422  304.709892  304.771572  304.641696
# 10        0.120984    2.983693  2.973220  376.684830  376.475759  376.475759
# ...

# %%
net.pipe
# Out:
#                            name  from_junction  to_junction std_type  \
# 0         Tubo_Ida_Plant_nodo_1              0            3     None
# 1      Tubo_RetornoPlant_nodo_1             21           18     None
# 2       Tubo_Ida_Plant_2_nodo_3              1            5     None
# 3    Tubo_RetornoPlant_2_nodo_3             23           19     None
# 4       Tubo_Ida_Plant_3_nodo_6              2            8     None
# 5    Tubo_RetornoPlant_3_nodo_6             26           20     None
# 6        Tubo_Ida_nodo_1_nodo_2              3            4     None
# 7    Tubo_Retorno_nodo_1_nodo_2             22           21     None
# 8        Tubo_Ida_nodo_1_nodo_3              3            5     None
# 9    Tubo_Retorno_nodo_1_nodo_3             23           21     None
# 10       Tubo_Ida_nodo_3_nodo_4              5            6     None
# 11   Tubo_Retorno_nodo_3_nodo_4             24           23     None
# 12       Tubo_Ida_nodo_4_nodo_5              6            7     None
# ...

# %%
net.res_circ_pump_pressure
# Out:
#    p_from_bar  p_to_bar    t_from_k  t_to_k  t_outlet_k  mdot_from_kg_per_s  \
# 0         2.5       3.0  304.735253   377.0       377.0            2.720634
#
#    mdot_to_kg_per_s  vdot_m3_per_s   deltat_k         qext_w
# 0         -2.720634       0.002789 -72.264747  825457.122841

# %%
net.res_circ_pump_mass
# Out:
#    p_from_bar  p_to_bar    t_from_k  t_to_k  t_outlet_k  mdot_from_kg_per_s  \
# 0    2.514841       5.0  304.625024   377.0       377.0            0.822722
# 1    2.523884       5.0  304.602672   376.0       376.0            1.000886
#
#    mdot_to_kg_per_s  vdot_m3_per_s   deltat_k         qext_w
# 0         -0.822722       0.000843 -72.374976  250000.000059
# 1         -1.000886       0.001026 -71.397328  300000.008923

# %%
net.res_flow_control
# Out:
#    p_from_bar  p_to_bar  t_from_k  t_to_k  t_outlet_k  mdot_from_kg_per_s  \
# 0         5.0  2.984599     377.0   377.0       377.0            0.822722
# 1         5.0  2.975229     376.0   376.0       376.0            1.000886
#
#    mdot_to_kg_per_s  vdot_m3_per_s
# 0         -0.822722       0.000861
# 1         -1.000886       0.001046
